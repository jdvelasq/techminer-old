# %%
# !paver local

# %%
rdf.columns
# Out:
# Index(['Authors', 'Author(s) ID', 'Title', 'Year', 'Source title', 'Volume',
#        'Issue', 'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by',
#        'DOI', 'Affiliations', 'Document Type', 'Access Type', 'Source', 'EID',
#        'Abstract', 'Author Keywords', 'Index Keywords', 'References',
#        'keywords', 'CONF', 'keywords (cleaned)', 'SELECTED', 'ID'],
#       dtype='object')

# %% [markdown]
# # Test

# %%
from techminer.datasets import load_test_cleaned
from techminer.dataframe import DataFrame

rdf = DataFrame(load_test_cleaned().data).generate_ID()
df = rdf.documents_by_term(column="Authors", top_n=10)
print(df)


Plot(df).wordcloud()

# Plot(df).pie()
# Plot(df).pie(cmap=plt.cm.Blues)

# Plot(df).barh()
#Plot(df).barh(cmap=plt.cm.Blues)
#Plot(df).plot('o-', color='red')
#df.plot.barh('Authors', 'Num Documents')
# Out:
#         Authors  Num Documents                             ID
# 0       Wang J.              7  [3, 10, 15, 80, 87, 128, 128]
# 1      Zhang G.              4             [27, 78, 117, 119]
# 2        Yan X.              3                   [13, 44, 85]
# 3  Hernandez G.              3                  [52, 94, 100]
# 4      Tefas A.              3                  [8, 110, 114]
# 5   Sandoval J.              3                  [52, 94, 100]
# 6  Iosifidis A.              3                  [8, 110, 114]
# 7      Zhang Y.              3                    [4, 6, 109]
# 8    Arévalo A.              3                  [52, 94, 100]
# 9         Wu J.              3                  [34, 66, 115]

# %%
"""
TechMiner.Plot
==================================================================================================




"""
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, ImageColorGenerator

class Plot:
    def __init__(self, pdf):
        self.pdf = pdf

    def wordcloud(
        self,
        font_path=None,
        width=400,
        height=200,
        margin=2,
        ranks_only=None,
        prefer_horizontal=0.9,
        mask=None,
        scale=1,
        color_func=None,
        max_words=200,
        min_font_size=4,
        stopwords=None,
        random_state=None,
        background_color="black",
        max_font_size=None,
        font_step=1,
        mode="RGB",
        relative_scaling="auto",
        regexp=None,
        collocations=True,
        colormap=None,
        normalize_plurals=True,
        contour_width=0,
        contour_color="black",
        repeat=False,
        include_numbers=False,
        min_word_length=0,
    ):
        """

        >>> import pandas as pd
        >>> import matplotlib.pyplot as plt
        >>> from techminer.datasets import load_test_cleaned
        >>> rdf = load_test_cleaned().data
        >>> rdf.documents_by_terms('Source title').wordcloud()

        .. image:: ../figs/wordcloud.jpg
            :width: 800px
            :align: center                
        """

        x = self.pdf.copy()
        x.pop("ID")
       
        words = [row[0] for _, row in x.iterrows() for i in range(row[1]) ]

        wordcloud = WordCloud(
            font_path=font_path,
            width=width,
            height=height,
            margin=margin,
            ranks_only=ranks_only,
            prefer_horizontal=prefer_horizontal,
            mask=mask,
            scale=scale,
            color_func=color_func,
            max_words=max_words,
            min_font_size=min_font_size,
            stopwords=stopwords,
            random_state=random_state,
            background_color=background_color,
            max_font_size=max_font_size,
            font_step=font_step,
            mode=mode,
            relative_scaling=relative_scaling,
            regexp=regexp,
            collocations=collocations,
            colormap=colormap,
            normalize_plurals=normalize_plurals,
            contour_width=contour_width,
            contour_color=contour_color,
            repeat=repeat,
            include_numbers=include_numbers,
            min_word_length=min_word_length,
        )
        
        wordcloud.generate(" ".join(words))

        plt.gca().imshow(wordcloud, interpolation="bilinear")
        plt.gca().axis("off")
        
        return plt.gca()

    def pie(
        self,
        cmap=plt.cm.Greys,
        explode=None,
        autopct=None,
        pctdistance=0.6,
        shadow=False,
        labeldistance=1.1,
        startangle=None,
        radius=None,
        counterclock=True,
        wedgeprops=None,
        textprops=None,
        center=(0, 0),
        frame=False,
        rotatelabels=False,
    ):

        x = self.pdf.copy()
        x.pop("ID")

        colors = None

        if cmap is not None:
            colors = [
                cmap(1.0 - 0.9 * (i / len(x))) for i in range(len(x[x.columns[1]]))
            ]

        plt.gca().pie(
            x=x[x.columns[1]],
            explode=explode,
            labels=x[x.columns[0]],
            colors=colors,
            autopct=autopct,
            pctdistance=pctdistance,
            shadow=shadow,
            labeldistance=labeldistance,
            startangle=startangle,
            radius=radius,
            counterclock=counterclock,
            wedgeprops=wedgeprops,
            textprops=textprops,
            center=center,
            frame=frame,
            rotatelabels=rotatelabels,
        )

        return plt.gca()

    def plot(self, *args, scalex=True, scaley=True, **kwargs):

        x = self.pdf.copy()
        x.pop("ID")

        plt.gca().plot(
            range(len(x)),
            x[x.columns[1]],
            *args,
            scalex=scalex,
            scaley=scaley,
            **kwargs,
        )

        plt.xticks(
            np.arange(len(x[x.columns[0]])), x[x.columns[0]], rotation="vertical"
        )
        plt.xlabel(x.columns[0])
        plt.ylabel(x.columns[1])

        plt.gca().spines["top"].set_visible(False)
        plt.gca().spines["right"].set_visible(False)
        plt.gca().spines["left"].set_visible(False)
        plt.gca().spines["bottom"].set_visible(False)

        return plt.gca()

    def barh(self, height=0.8, left=None, align="center", cmap=None, **kwargs):

        x = self.pdf.copy()
        x.pop("ID")

        if cmap is not None:

            kwargs["color"] = [
                cmap((0.2 + 0.75 * x[x.columns[1]][i] / max(x[x.columns[1]])))
                for i in range(len(x[x.columns[1]]))
            ]

        plt.gca().barh(
            y=range(len(x)),
            width=x[x.columns[1]],
            height=height,
            left=left,
            align=align,
            **kwargs,
        )

        plt.gca().invert_yaxis()

        plt.yticks(np.arange(len(x[x.columns[0]])), x[x.columns[0]])
        plt.xlabel(x.columns[1])
        plt.ylabel(x.columns[0])

        plt.gca().spines["top"].set_visible(False)
        plt.gca().spines["right"].set_visible(False)
        plt.gca().spines["left"].set_visible(False)
        plt.gca().spines["bottom"].set_visible(False)

        return plt.gca()

    def bar(self, width=0.8, bottom=None, align="center", cmap=plt.cm.Greys, **kwargs):

        x = self.pdf.copy()
        x.pop("ID")

        if cmap is not None:

            kwargs["color"] = [
                cmap((0.2 + 0.75 * x[x.columns[1]][i] / max(x[x.columns[1]])))
                for i in range(len(x[x.columns[1]]))
            ]

        result = plt.gca().bar(
            x=range(len(x)),
            height=x[x.columns[1]],
            width=width,
            bottom=bottom,
            align=align,
            **({}),
            **kwargs,
        )
        plt.xticks(
            np.arange(len(x[x.columns[0]])), x[x.columns[0]], rotation="vertical"
        )
        plt.xlabel(x.columns[0])
        plt.ylabel(x.columns[1])

        plt.gca().spines["top"].set_visible(False)
        plt.gca().spines["right"].set_visible(False)
        plt.gca().spines["left"].set_visible(False)
        plt.gca().spines["bottom"].set_visible(False)

        # plt.gca().invert_yaxis()

        return plt.gca()

    # ----------------------------------------------------------------------------------------------------

    def heatmap(
        self,
        ascending_r=None,
        ascending_c=None,
        alpha=None,
        norm=None,
        cmap=plt.cm.Greys,
        vmin=None,
        vmax=None,
        data=None,
        **kwargs
    ):
        """Heat map.


        https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn'


        >>> from techminer.datasets import load_test_cleaned
        >>> from techminer.dataframe import DataFrame
        >>> rdf = DataFrame(load_test_cleaned().data).generate_ID()
        >>> result = rdf.co_ocurrence(column_r='Authors', column_c='Document Type', top_n=5)
        >>> from techminer.plot import Plot
        >>> Plot(result).heatmap()

        .. image:: ../figs//heatmap.jpg
            :width: 600px
            :align: center

        """

        x = self.pdf.copy()
        x.pop("ID")
        x = pd.pivot_table(
            data=x,
            index=x.columns[0],
            columns=x.columns[1],
            margins=False,
            fill_value=0,
        )
        x.columns = [b for _, b in x.columns]
        result = plt.gca().pcolor(
            x.values,
            alpha=alpha,
            norm=norm,
            cmap=cmap,
            vmin=vmin,
            vmax=vmax,
            data=data,
            **({}),
            **kwargs,
        )
        plt.xticks(np.arange(len(x.index)) + 0.5, x.index, rotation="vertical")
        plt.yticks(np.arange(len(x.columns)) + 0.5, x.columns)
        plt.gca().invert_yaxis()

        return plt.gca()

        # ## force the same order of cells in rows and cols ------------------------------------------
        # if self._call == 'auto_corr':
        #     if ascending_r is None and ascending_c is None:
        #         ascending_r = True
        #         ascending_c = True
        #     elif ascending_r is not None and ascending_r != ascending_c:
        #         ascending_c = ascending_r
        #     elif ascending_c is not None and ascending_c != ascending_r:
        #         ascending_r = ascending_c
        #     else:
        #         pass
        # ## end -------------------------------------------------------------------------------------

        x = self.tomatrix(ascending_r, ascending_c)

        ## rename columns and row index
        # x.columns = [cut_text(w) for w in x.columns]
        # x.index = [cut_text(w) for w in x.index]

        # if self._call == 'factor_analysis':
        #     x = self.tomatrix(ascending_r, ascending_c)
        #     x = x.transpose()
        #     plt.pcolor(np.transpose(abs(x.values)), cmap=cmap)
        # else:
        #     plt.pcolor(np.transpose(x.values), cmap=cmap)

        # plt.xticks(np.arange(len(x.index))+0.5, x.index, rotation='vertical')
        # plt.yticks(np.arange(len(x.columns))+0.5, x.columns)
        # plt.gca().invert_yaxis()

        ## changes the color of rectangle for autocorrelation heatmaps ---------------------------

        # if self._call == 'auto_corr':
        #     for idx in np.arange(len(x.index)):
        #         plt.gca().add_patch(
        #             Rectangle((idx, idx), 1, 1, fill=False, edgecolor='red')
        #         )

        ## end ------------------------------------------------------------------------------------

        ## annotation
        # for idx_row, row in enumerate(x.index):
        #     for idx_col, col in enumerate(x.columns):

        #         if self._call in ['auto_corr', 'cross_corr', 'factor_analysis']:

        #             if abs(x.at[row, col]) > x.values.max() / 2.0:
        #                 color = 'white'
        #             else:
        #                 color = 'black'

        #             plt.text(
        #                 idx_row + 0.5,
        #                 idx_col + 0.5,
        #                 "{:3.2f}".format(x.at[row, col]),
        #                 ha="center",
        #                 va="center",
        #                 color=color)

        #         else:
        #             if x.at[row, col] > 0:

        #                 if x.at[row, col] > x.values.max() / 2.0:
        #                     color = 'white'
        #                 else:
        #                     color = 'black'

        #                 plt.text(
        #                     idx_row + 0.5,
        #                     idx_col + 0.5,
        #                     int(x.at[row, col]),
        #                     ha="center",
        #                     va="center",
        #                     color=color)

        # plt.tight_layout()
        # plt.show()

# %%
for i, c in enumerate(
    []
):
    print(i, c)
# Out:
# 0 Ź
# 1 Ż
# 2 Ž
# 3 ---
# 4 ž
# 5 ź
# 6 ż

# %%
rdf = DataFrame(load_test_cleaned().data).generate_ID()[['Authors', 'Author(s) ID']]
for row in rdf.iterrows():
    print(row)
# Out:
# (0, Authors         Hajiabotorabi Z., Kazemi A., Samavati F.F., Ma...
# Author(s) ID      57210187197;24070754400;6603142390;26644170500;
# Name: 0, dtype: object)
# (1, Authors         Ładyżyński P., Żbikowski K., Gawrysiak P.
# Author(s) ID         55897965200;55860046500;24337898500;
# Name: 1, dtype: object)
# (2, Authors         Rodrigues F., Markou I., Pereira F.C.
# Author(s) ID      36647999000;56724096100;7201689596;
# Name: 2, dtype: object)
# (3, Authors                  Cao J., Wang J.
# Author(s) ID    57207830408;57207828548;
# Name: 3, dtype: object)
# (4, Authors              Xing F.Z., Cambria E., Zhang Y.
# Author(s) ID    57196019442;56140547500;56462264800;
# Name: 4, dtype: object)
# (5, Authors              Zhang Z., Zohren S., Roberts S.
# Author(s) ID    57208652822;14057447500;57203276441;
# Name: 5, dtype: object)
# (6, Authors             Shi L., Teng Z., Wang L., Zhang Y., Binder A.
# Author(s) ID    55520303300;57191849336;57189032831;5720289057...
# Name: 6, dtype: object)
# (7, Authors               Yeze Z., Yiying W.
# Author(s) ID    57209140407;57209134544;
# Name: 7, dtype: object)
# (8, Authors         Passalis N., Tefas A., Kanniainen J., Gabbouj ...
# Author(s) ID    56897101400;6701672908;23394868200;7005332419;...
# Name: 8, dtype: object)
# (9, Authors         Karmiani D., Kazi R., Nambisan A., Shah A., Ka...
# Author(s) ID    57208722670;57208718984;57208719870;5720872154...
# Name: 9, dtype: object)
# (10, Authors                 Wang B., Wang J.
# Author(s) ID    57205691331;55946707000;
# Name: 10, dtype: object)
# (11, Authors         Moews B., Herrmann J.M., Ibikunle G.
# Author(s) ID    57204789588;16412284700;55509976400;
# Name: 11, dtype: object)
# (12, Authors         Sismanoglu G., Onde M.A., Kocer F., Sahingoz O.K.
# Author(s) ID     57209730058;57209731841;57209734258;14054797000;
# Name: 12, dtype: object)
# (13, Authors                  Yan X., Zhao J.
# Author(s) ID    50562404800;57206579718;
# Name: 13, dtype: object)
# (14, Authors               Yu M.-H., Wu J.-L.
# Author(s) ID    57208408426;36816648000;
# Name: 14, dtype: object)
# (15, Authors                          Du J., Liu Q., Chen K., Wang J.
# Author(s) ID    15060001900;57209464952;57209470539;57209477365;
# Name: 15, dtype: object)
# (16, Authors         Thipprachak K., Tangamchit P.
# Author(s) ID          57207926780;6506821304;
# Name: 16, dtype: object)
# (17, Authors                  Wu C.-H., Lu C.-C., Ma Y.-F., Lu R.-S.
# Author(s) ID    55713072400;57207760751;57207762684;7402969813;
# Name: 17, dtype: object)
# (18, Authors         Borovykh A., Bohte S., Oosterlee C.W.
# Author(s) ID      57193126885;55893905100;6701797256;
# Name: 18, dtype: object)
# (19, Authors          Huang H.-S., Liu C.-L., Tseng V.S.
# Author(s) ID    57196051044;57129735000;6507335623;
# Name: 19, dtype: object)
# (20, Authors         Hossain M.A., Karim R., Thulasiram R., Bruce N...
# Author(s) ID    57207728673;55407386600;6602683636;8347469300;...
# Name: 20, dtype: object)
# (21, Authors         Uygun Y., Erboy M.O., Aktas M.S., Kalipsiz O.,...
# Author(s) ID    57207696480;57190650159;8410237700;13408912900...
# Name: 21, dtype: object)
# (22, Authors         Islam S.R., Khaled Ghafoor S., Eberle W.
# Author(s) ID        57195922078;57207579157;24558789000;
# Name: 22, dtype: object)
# (23, Authors         Siami-Namini S., Tavakoli N., Siami Namin A.
# Author(s) ID            57201302278;57198291892;36171214700;
# Name: 23, dtype: object)
# (24, Authors         Morris K.J., Egan S.D., Linsangan J.L., Leung ...
# Author(s) ID    57198863686;57207108540;57207114198;7402612526...
# Name: 24, dtype: object)
# (25, Authors                       Long W., Lu Z., Cui L.
# Author(s) ID    36792418900;57207322594;57189992988;
# Name: 25, dtype: object)
# (26, Authors                    Le L., Xie Y.
# Author(s) ID    57193344346;55710281400;
# Name: 26, dtype: object)
# (27, Authors                    Zheng J., Fu X., Zhang G.
# Author(s) ID    44062068800;57005856100;56949237700;
# Name: 27, dtype: object)
# (28, Authors         Yasir M., Durrani M.Y., Afzal S., Maqsood M., ...
# Author(s) ID    35231560800;24775626200;57210197386;5719781009...
# Name: 28, dtype: object)
# (29, Authors                    Zhang C., Dai Q., Song G.
# Author(s) ID    56072612200;35315440400;57104239400;
# Name: 29, dtype: object)
# (30, Authors          Moro G., Pasolini R., Domeniconi G., Ghini V.
# Author(s) ID    8702087400;56412031400;56411905800;6507031598;
# Name: 30, dtype: object)
# (31, Authors         Weytjens H., Lohmann E., Kleinsteuber M.
# Author(s) ID         37071509600;57195594980;8257006600;
# Name: 31, dtype: object)
# (32, Authors         Liashenko O., Kravets T.
# Author(s) ID    57210112572;14063413700;
# Name: 32, dtype: object)
# (33, Authors           Lee R.S.T.
# Author(s) ID    57209821688;
# Name: 33, dtype: object)
# (34, Authors                Fu X., Zhang S., Chen J., Ouyang T., Wu J.
# Author(s) ID    36614138900;57203165289;55925522600;5720977439...
# Name: 34, dtype: object)
# (35, Authors           Sirignano J., Cont R.
# Author(s) ID    35753895800;6602945666;
# Name: 35, dtype: object)
# (36, Authors             Miura R., Pichl L., Kaizoji T.
# Author(s) ID    57209745684;6701314709;6603679407;
# Name: 36, dtype: object)
# (37, Authors                Lu M.
# Author(s) ID    57209638825;
# Name: 37, dtype: object)
# (38, Authors                  Yang X., Mao S., Gao H., Duan Y., Zou Q.
# Author(s) ID    57189699603;57092455700;36442463200;5632855620...
# Name: 38, dtype: object)
# (39, Authors         Siddiqui S.A., Mercier D., Munir M., Dengel A....
# Author(s) ID    57200439899;57197827803;57201250579;6603764314...
# Name: 39, dtype: object)
# (40, Authors             Ni L., Li Y., Wang X., Zhang J., Yu J., Qi C.
# Author(s) ID    7102681459;57201377077;57201523676;52164985200...
# Name: 40, dtype: object)
# (41, Authors          Bhowmick A., Rahman A., Rahman R.M.
# Author(s) ID    57208836861;20535568700;57202814494;
# Name: 41, dtype: object)
# (42, Authors            Hsu E.-Y., Liu C.-L., Tseng V.S.
# Author(s) ID    57208527341;57129735000;6507335623;
# Name: 42, dtype: object)
# (43, Authors         Au Yeung J.F.K., Wei Z.-K., Chan K.Y., Lau H.Y...
# Author(s) ID    57208441553;57200795560;55647800400;7201497761...
# Name: 43, dtype: object)
# (44, Authors                    Yu P., Yan X.
# Author(s) ID    57208402963;23391007200;
# Name: 44, dtype: object)
# (45, Authors         De Stefani J., Caelen O., Hattab D., LeÂ Borgn...
# Author(s) ID    57196261818;15623146800;57196257647;5720798029...
# Name: 45, dtype: object)
# (46, Authors                         Wen M., Li P., Zhang L., Chen Y.
# Author(s) ID    57207925743;57193136585;57207942564;56928458300;
# Name: 46, dtype: object)
# (47, Authors                           Liu F., Cai M., Wang L., Lu Y.
# Author(s) ID    16039764100;57207691663;54397764100;57207696983;
# Name: 47, dtype: object)
# (48, Authors            Berradi Z., Lazaar M.
# Author(s) ID    57207622928;57200595982;
# Name: 48, dtype: object)
# (49, Authors         Brando A., Rodríguez-Serrano J.A., Ciprian M.,...
# Author(s) ID    57205697622;26538208800;57205694376;5720477084...
# Name: 49, dtype: object)
# (50, Authors               Sethia A., Raut P.
# Author(s) ID    57205209102;57203153335;
# Name: 50, dtype: object)
# (51, Authors              Pawar K., Jalem R.S., Tiwari V.
# Author(s) ID    57204828764;57204832113;56496391800;
# Name: 51, dtype: object)
# (52, Authors         Niño J., Hernandez G., Arévalo A., Leon D., Sa...
# Author(s) ID    57190225431;35897064300;57190281278;5719535022...
# Name: 52, dtype: object)
# (53, Authors         Althelaya K.A., El-Alfy E.-S.M., Mohammed S.
# Author(s) ID              57202503786;7003943902;7102894386;
# Name: 53, dtype: object)
# (54, Authors                Baek Y., Kim H.Y.
# Author(s) ID    57202960071;57200074208;
# Name: 54, dtype: object)
# (55, Authors                         Wang Y., Liu Y., Wang M., Liu R.
# Author(s) ID    57205507649;57205509553;55561302000;36606572600;
# Name: 55, dtype: object)
# (56, Authors              Gurav U., Sidnal N.
# Author(s) ID    36052794200;24462689600;
# Name: 56, dtype: object)
# (57, Authors           Kumar S., Ningombam D.
# Author(s) ID    57209548409;57200762188;
# Name: 57, dtype: object)
# (58, Authors         Manurung A.H., Budiharto W., Prabowo H.
# Author(s) ID       57207622302;36069151100;57210847043;
# Name: 58, dtype: object)
# (59, Authors                   Tsang G., Deng J., Xie X.
# Author(s) ID    57205363535;55922714500;7402761335;
# Name: 59, dtype: object)
# (60, Authors             Day M.-Y., Lin J.-T., Chen Y.-C.
# Author(s) ID    14031006200;57204820145;57204820974;
# Name: 60, dtype: object)
# (61, Authors         Machado E.J., Pereira A.C.M.
# Author(s) ID        57192673413;35579191200;
# Name: 61, dtype: object)
# (62, Authors            Fischer T., Krauss C.
# Author(s) ID    55757780995;57189242463;
# Name: 62, dtype: object)
# (63, Authors         Pereira D.F.R., Junior N.N.D.M., Caloba L.P.
# Author(s) ID            57204639812;57204645429;24282923400;
# Name: 63, dtype: object)
# (64, Authors                      Jiang X., Pan S., Jiang J., Long G.
# Author(s) ID    57013726600;55522732400;55731807500;55522990400;
# Name: 64, dtype: object)
# (65, Authors                     Yao S., Luo L., Peng H.
# Author(s) ID    57204428087;17345995600;9732506800;
# Name: 65, dtype: object)
# (66, Authors                        Chen Y., Wu J., Bu H.
# Author(s) ID    57204076092;57204072042;57204073569;
# Name: 66, dtype: object)
# (67, Authors         Sezer O.B., Ozbayoglu A.M.
# Author(s) ID       57207586168;6505999525;
# Name: 67, dtype: object)
# (68, Authors                Yan H., Ouyang H.
# Author(s) ID    57198790516;35269370400;
# Name: 68, dtype: object)
# (69, Authors         Alkhoshi E., Belkasim S.
# Author(s) ID     57205116311;6603864907;
# Name: 69, dtype: object)
# (70, Authors         Chiong R., Adam M.T.P., Fan Z., Lutz B., Hu Z....
# Author(s) ID    23395951300;44061092000;57007544300;5719026213...
# Name: 70, dtype: object)
# (71, Authors                   Du S., Li T., Horng S.-J.
# Author(s) ID    57194798613;7406372548;35585485600;
# Name: 71, dtype: object)
# (72, Authors           Katarya R., Mahajan A.
# Author(s) ID    35810442400;57208733585;
# Name: 72, dtype: object)
# (73, Authors                  Zhang R., Yuan Z., Shao X.
# Author(s) ID    56402104400;57203940881;7202920566;
# Name: 73, dtype: object)
# (74, Authors                          Zhao Z., Rao R., Tu S., Shi J.
# Author(s) ID    57195064100;7403068844;57202467255;57202460505;
# Name: 74, dtype: object)
# (75, Authors                 Tang J., Chen X.
# Author(s) ID    57204393943;35204856400;
# Name: 75, dtype: object)
# (76, Authors         Janardhanan D., Barrett E.
# Author(s) ID      57202363941;27567564400;
# Name: 76, dtype: object)
# (77, Authors         Perfilieva I.
# Author(s) ID      6602820249;
# Name: 77, dtype: object)
# (78, Authors              Zhang Z., Shen Y., Zhang G., Song Y., Zhu Y.
# Author(s) ID    57202058986;56528648300;15077721900;5719383101...
# Name: 78, dtype: object)
# (79, Authors                      Zhang L., Fan X., Xu C.
# Author(s) ID    57207391748;18041619200;55600419500;
# Name: 79, dtype: object)
# (80, Authors                     Dong Y., Wang J., Guo Z.
# Author(s) ID    57194399361;56380147600;37002500800;
# Name: 80, dtype: object)
# (81, Authors         Samarawickrama A.J.P., Fernando T.G.I.
# Author(s) ID                   57203114328;7004517726;
# Name: 81, dtype: object)
# (82, Authors                   Li W., Liao J.
# Author(s) ID    56177322400;57201553186;
# Name: 82, dtype: object)
# (83, Authors         Ugur Gudelek M., Arda Boluk S., Murat Ozbayogl...
# Author(s) ID                 57201792615;57201796716;57200377068;
# Name: 83, dtype: object)
# (84, Authors                       Yin Q., Zhang R., Liu Y., Shao X.
# Author(s) ID    57201996015;56402104400;57201990786;7202920566;
# Name: 84, dtype: object)
# (85, Authors                    Yan X., Zhang W., Ma L., Liu W., Wu Q.
# Author(s) ID    57208444896;56393387800;56377428300;5630362540...
# Name: 85, dtype: object)
# (86, Authors             Qiao M., Huang K.-W.
# Author(s) ID    57207454883;28367654100;
# Name: 86, dtype: object)
# (87, Authors                         Luo R., Zhang W., Xu X., Wang J.
# Author(s) ID    57204819270;56108513500;57206642524;57206677306;
# Name: 87, dtype: object)
# (88, Authors                    Yang H., Zhu Y., Huang Q.
# Author(s) ID    57205196792;55648689000;56010143500;
# Name: 88, dtype: object)
# (89, Authors         Zhu H., Zhu Y., Wu D., Wang H., Tian L., Mao W...
# Author(s) ID    57205095793;36903371100;57207184322;5587725330...
# Name: 89, dtype: object)
# (90, Authors         Jayanth Balaji A., Harish Ram D.S., Nair B.B.
# Author(s) ID             56607264800;49963634900;35386974400;
# Name: 90, dtype: object)
# (91, Authors                 Shen G., Tan Q., Zhang H., Zeng P., Xu J.
# Author(s) ID    57205712383;13404486500;57193803016;5695775550...
# Name: 91, dtype: object)
# (92, Authors           Tsai Y.-C., Chen J.-H., Wang J.-J.
# Author(s) ID    57203011511;57204046656;57204046789;
# Name: 92, dtype: object)
# (93, Authors         Heinrich K., Fleißner V.
# Author(s) ID    55204945400;57203926859;
# Name: 93, dtype: object)
# (94, Authors         Niño J., Arévalo A., Leon D., Hernandez G., Sa...
# Author(s) ID    57190225431;57190281278;57195350225;3589706430...
# Name: 94, dtype: object)
# (95, Authors               Lee S.I., Yoo S.J.
# Author(s) ID    57203921315;55665769500;
# Name: 95, dtype: object)
# (96, Authors         Bahrpeyma F., Roantree M., McCarren A.
# Author(s) ID       55959195700;6602546023;55894976400;
# Name: 96, dtype: object)
# (97, Authors         Zhan X., Li Y., Li R., Gu X., Habimana O., Wan...
# Author(s) ID    57203548515;55719078700;7404724385;13408314400...
# Name: 97, dtype: object)
# (98, Authors                   Sun H., Guo C., Xu J., Zhu J., Zhang C.
# Author(s) ID    57202469424;35731095300;56115674400;5719406779...
# Name: 98, dtype: object)
# (99, Authors                       Lu Z., Long W., Guo Y.
# Author(s) ID    57207322594;36792418900;57202708122;
# Name: 99, dtype: object)
# (100, Authors         Arévalo A., Nino J., León D., Hernandez G., Sa...
# Author(s) ID    57190281278;57190225431;57195350225;3589706430...
# Name: 100, dtype: object)
# (101, Authors                 Zhang X., Tan Y.
# Author(s) ID    57202682531;56098810800;
# Name: 101, dtype: object)
# (102, Authors                      Sun S., Wei Y., Wang S.
# Author(s) ID    57193552421;57194829641;35195168500;
# Name: 102, dtype: object)
# (103, Authors         Di Persio L., Honchar O.
# Author(s) ID    57203636440;57192153071;
# Name: 103, dtype: object)
# (104, Authors             Dixon M.
# Author(s) ID    55982004900;
# Name: 104, dtype: object)
# (105, Authors                      Liu C., Hou W., Liu D.
# Author(s) ID    57194109538;8430631300;56562006300;
# Name: 105, dtype: object)
# (106, Authors         Selvin S., Vinayakumar R., Gopalakrishnan E.A....
# Author(s) ID    57191042609;56755324000;43761171400;5687244810...
# Name: 106, dtype: object)
# (107, Authors            Korczak J., Hemes M.
# Author(s) ID    7004001261;57200141372;
# Name: 107, dtype: object)
# (108, Authors         Afolabi D., Guan S.-U., Man K.L., Wong P.W.H.,...
# Author(s) ID    55791007800;56000571900;55536496100;9734871500...
# Name: 108, dtype: object)
# (109, Authors           Chen W., Zhang Y., Yeo C.K., Lau C.T., Lee B.S.
# Author(s) ID    57188997356;56825288900;7102545548;7401968617;...
# Name: 109, dtype: object)
# (110, Authors         Tsantekidis A., Passalis N., Tefas A., Kanniai...
# Author(s) ID    57195636516;56897101400;6701672908;23394868200...
# Name: 110, dtype: object)
# (111, Authors         Dingli A., Fournier K.S.
# Author(s) ID     7801315512;57197812381;
# Name: 111, dtype: object)
# (112, Authors                 Rout A.K., Dash P.K., Dash R., Bisoi R.
# Author(s) ID    55602137700;7102314306;42560989800;54941427900;
# Name: 112, dtype: object)
# (113, Authors          Singh R., Srivastava S.
# Author(s) ID    57202825807;57192430115;
# Name: 113, dtype: object)
# (114, Authors         Tsantekidis A., Passalis N., Tefas A., Kanniai...
# Author(s) ID    57195636516;56897101400;6701672908;23394868200...
# Name: 114, dtype: object)
# (115, Authors                          Li J., Bu H., Wu J.
# Author(s) ID    57195521810;57204073569;35313047900;
# Name: 115, dtype: object)
# (116, Authors         Chen J.-F., Chen W.-L., Huang C.-P., Huang S.-...
# Author(s) ID    57195363174;57195360094;57195361498;8882763200...
# Name: 116, dtype: object)
# (117, Authors                     Zhang G., Xu L., Xue Y.
# Author(s) ID    56670483600;7404745474;56278752300;
# Name: 117, dtype: object)
# (118, Authors         Galeshchuk S., Mukherjee S.
# Author(s) ID        56205106000;7401816816;
# Name: 118, dtype: object)
# (119, Authors                      Yu H., Xu L., Zhang G.
# Author(s) ID    57197735758;7404745474;56670483600;
# Name: 119, dtype: object)
# (120, Authors         Borovykh A., Bohte S., Oosterlee C.W.
# Author(s) ID      57193126885;55893905100;6701797256;
# Name: 120, dtype: object)
# (121, Authors         Figueroa-García J.C., LóPez-Santana E., Franco...
# Author(s) ID                 24767828800;57189442448;56583596000;
# Name: 121, dtype: object)
# (122, Authors         Buczkowski P.
# Author(s) ID     57194777223;
# Name: 122, dtype: object)
# (123, Authors         Karathanasopoulos A.
# Author(s) ID            36608193100;
# Name: 123, dtype: object)
# (124, Authors         Akita R., Yoshihara A., Matsubara T., Uehara K.
# Author(s) ID    57191226854;56425644100;53863900700;7201993612;
# Name: 124, dtype: object)
# (125, Authors         Hussain A.J., Al-Jumeily D., Al-Askar H., Radi N.
# Author(s) ID      56212648400;23090210900;56288742400;6505760939;
# Name: 125, dtype: object)
# (126, Authors         Horelu A., Leordeanu C., Apostol E., Huru D., ...
# Author(s) ID    57189040270;23469633000;55365937600;5718903482...
# Name: 126, dtype: object)
# (127, Authors         Di Persio L., Honchar O.
# Author(s) ID    57203636440;57192153071;
# Name: 127, dtype: object)
# (128, Authors                        Wang J., Wang J., Fang W., Niu H.
# Author(s) ID    56527464300;55946707000;42361194900;55286614500;
# Name: 128, dtype: object)
# (129, Authors         Nascimento J.B., Cristo M.
# Author(s) ID       57169827100;8358717400;
# Name: 129, dtype: object)
# (130, Authors          Bebarta D.K., Biswal B., Dash P.K.
# Author(s) ID    36809160400;16642346800;7102314306;
# Name: 130, dtype: object)
# (131, Authors           Zafari F., Khan G.M., Rehman M., Ali Mahmud S.
# Author(s) ID    56028822400;19639163400;56278299400;56278649100;
# Name: 131, dtype: object)
# (132, Authors         Ortega L., Khashanah K.
# Author(s) ID    55797136900;6506999405;
# Name: 132, dtype: object)
# (133, Authors         Bekiros S.D.
# Author(s) ID     8560165000;
# Name: 133, dtype: object)
# (134, Authors         Sharma V., Srinivasan D.
# Author(s) ID     57199918726;7006684979;
# Name: 134, dtype: object)
# (135, Authors                      Cai X., Lai G., Lin X.
# Author(s) ID    55366093200;56256904700;8208832700;
# Name: 135, dtype: object)
# (136, Authors         Zimmermann H.G., Grothmann R., von Mettenheim ...
# Author(s) ID                  35615968500;23024809400;8947545100;
# Name: 136, dtype: object)
# (137, Authors          Wei L.-Y., Cheng C.-H.
# Author(s) ID    23062367300;7404797459;
# Name: 137, dtype: object)
# (138, Authors          Ortega L.F.
# Author(s) ID    55797136900;
# Name: 138, dtype: object)
# (139, Authors         Ghazali R., Hussain A.J., Liatsis P.
# Author(s) ID     23388956400;56212648400;8410551000;
# Name: 139, dtype: object)
# (140, Authors         Hsieh T.-J., Hsiao H.-F., Yeh W.-C.
# Author(s) ID    36188164200;35292259200;7202860325;
# Name: 140, dtype: object)
# (141, Authors         [No author name available]
# Author(s) ID      [No author id available]
# Name: 141, dtype: object)
# (142, Authors          Dunis C.L., Laws J., Sermpinis G.
# Author(s) ID    6602234892;7005939268;35099556100;
# Name: 142, dtype: object)
# (143, Authors                        Zhai F., Lin X., Yang Z., Song Y.
# Author(s) ID    35747648300;24338421700;55832871000;15124457200;
# Name: 143, dtype: object)

# %%
                                         Authors                                     Author(s) ID   ID
Wang J.                          57207828548    3
Wang J.*                         55946707000   10
Wang J.**                        57209477365   15
Wang J.***                       56380147600   80
Wang J.****                      57206677306   87
Wang J.*****,Wang J.*            56527464300;55946707000
