# %% [markdown]
# # Autocorrelation matrix (Experimental)

# %%
#
# Data loading
#
import pandas as pd

url = "https://raw.githubusercontent.com/jdvelasq/techminer/master/data/tutorial/"

df = pd.read_json(url + "cleaned-data.json", orient="records", lines=True)

# %%
import matplotlib.pyplot as plt
from techminer import DataFrame, Plot

df = DataFrame(df)

# %% [markdown]
# ## Authors

# %%
rdf.auto_corr(column="Authors", sep=",", top_n=10).heatmap(figsize=(8, 8))

# %%
rdf.auto_corr(column="Authors", sep=",", top_n=20).heatmap(figsize=(10, 10))

# %%
rdf.auto_corr(column="Authors", sep=",", top_n=30).heatmap(figsize=(12, 12))

# %%
rdf.auto_corr(column="Authors", sep=",", top_n=20).map(figsize=(10, 10))

# %%
rdf.auto_corr(column="Authors", sep=",", top_n=20).chord_diagram(figsize=(10, 10))

# %% [markdown]
# ## Keywords

# %%
rdf.auto_corr(column="keywords (cleaned)", sep=";", top_n=10).heatmap(figsize=(8, 8))

# %%
rdf.auto_corr(column="keywords (cleaned)", sep=";", top_n=20).heatmap(figsize=(12, 12))

# %%
rdf.auto_corr(column="keywords (cleaned)", sep=";", top_n=30).heatmap(figsize=(14, 14))

# %%
rdf.auto_corr(column="keywords (cleaned)", sep=";", top_n=20).map(figsize=(12, 12))

# %%
rdf.auto_corr(column="keywords (cleaned)", sep=";", top_n=20).chord_diagram(
    figsize=(12, 12)
)
